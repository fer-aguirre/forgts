# %%
from forgts import format_gt_from_excel

gt_object = format_gt_from_excel("./example.xlsx")

gt_object
# Out:
# INFO:forgts:Starting the formatting process from Excel.
# INFO:forgts:Extracting formatting information.
# INFO:forgts:Translating formatting to great_tables format.
# INFO:forgts:Applying formatting to the GT object.
# INFO:forgts:Formatting process completed.
# GT(_tbl_data=  measurement type                species sex    CBL     LR
# 0     craniodental      Abeomelomys sevia   m  30.10   9.65
# 1     craniodental  Bandicota bengalensis   f  39.41  11.21
# 2     craniodental     Chiruromys forbesi   m  30.73   8.27
# 3     craniodental     Chiruromys forbesi   m  34.46   8.13
# 4     craniodental       Chiruromys lamia   m  29.56   8.13
# 5     craniodental       Chiruromys lamia   m  27.45   7.13
# ...
